# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragavi1974/BeautyVerseAI/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("appliance_energy.csv")
df.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
missing=df.isnull().sum()
missing_percentage=(missing/len(df))*100
print(missing_percentage)

print("\nDatafeame columns:")
print(df.columns)
# Out:
# Temperature (°C)            0.0
# Energy Consumption (kWh)    0.0
# dtype: float64
#
# Datafeame columns:
# Index(['Temperature (°C)', 'Energy Consumption (kWh)'], dtype='object')

# %%
X=df[["Temperature (°C)"]]
Y=df["Energy Consumption (kWh)"]

# %%
X.shape
# Out:
# (100, 1)

# %%
Y.shape
# Out:
# (100,)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (80, 1)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# [1.6858187  3.18154068 2.96097494 2.76354868 2.0370856  2.36343345
#  2.09711944 3.12445907 1.60849483 2.24537556 2.34866555 2.66462648
#  3.0387357  3.27880886 1.78664542 1.85218469 2.95922164 1.70468695
#  3.0692904  1.87828475]

# %%
X_test
# Out:
#     Temperature (°C)
# 83         16.271167
# 53         32.896547
# 70         30.444895
# 45         28.250446
# 44         20.175600
# 39         23.803050
# 22         20.842893
# 80         32.262069
# 10         15.411690
# 0          22.490802
# 18         23.638900
# 30         27.150897
# 73         31.309229
# 33         33.977711
# 90         17.391885
# 4          18.120373
# 76         30.425407
# 77         16.480893
# 12         31.648853
# 31         18.410482

# %%
Y_test
# Out:
# 83    1.955394
# 53    3.037917
# 70    2.426014
# 45    2.370351
# 44    2.413076
# 39    2.531079
# 22    2.086846
# 80    4.159094
# 10    1.998870
# 0     2.292604
# 18    2.167836
# 30    3.658183
# 73    3.279415
# 33    3.360548
# 90    2.150219
# 4     1.702201
# 76    2.702528
# 77    1.764216
# 12    2.900005
# 31    1.928337
# Name: Energy Consumption (kWh), dtype: float64

# %%
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print("Mean Squared Error:",mse)
print("R-squared:",r2)
# Out:
# Mean Squared Error: 0.16342487842925055
# R-squared: 0.6119478445218713

# %%
plt.scatter(X_test,Y_test,color='blue',label='Test Data')
plt.plot(X_test,y_pred,color='red',linewidth=2,label='Regression line')
plt.xlabel("Temperature (°C)")
plt.ylabel("Energy Consumption (kWh)")
plt.title("Temperature vs Energy Consumption")
plt.legend()
